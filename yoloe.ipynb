# %%
from ultralytics import YOLOE
model = YOLOE('yoloe-11l-seg-pf.pt')
model.info()
# Out:
# ...
# YOLOe-11l-seg summary: 415 layers, 36,714,830 parameters, 29,974,133 gradients, 144.8 GFLOPs
# (415, 36714830, 29974133, 144.8057344)

# %%
results = model(
    "room.jpg",
    imgsz=640,
    device=0,        # use GPU
    conf=0.25        # confidence threshold
)

results[0].show()
# Out:
# image 1/1 c:\Users\ASUS\Desktop\promethean\som ting wong\room.jpg: 480x640 1 basket container, 1 clock, 3 bottles, 2 CDs, 1 cigar box, 1 clutch bag, 1 computer chair, 1 keyboard, 1 converter, 1 crt screen, 1 envelope, 1 hassock, 1 hat, 1 jug, 1 monitor, 2 mouses, 1 musical keyboard, 1 office chair, 1 office desk, 1 pen, 2 pencils, 1 remote, 1 rubik's cube, 1 stool, 1 storage box, 1 television, 1 thimble, 1 tissue, 89.0ms
# Speed: 5.1ms preprocess, 89.0ms inference, 25.0ms postprocess per image at shape (1, 3, 480, 640)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 8
#       1 results = model(
#       2     "room.jpg",
#       3     imgsz=640,
#       4     device=0,        # use GPU
#       5     conf=0.25        # confidence threshold
#       6 )
# ----> 8 results[0].show()
#
# ...

# %%
from ultralytics import YOLOE
from ultralytics.models.yolo.yoloe import YOLOEPETrainer

model = YOLOE("yoloe-11s.yaml")

model.load("yoloe-11s-seg.pt")

results = model.train(
    data=r"C:\Users\ASUS\Desktop\promethean\som ting wong\chess_pieces_no2\data.yaml",
    epochs=80,
    patience=10,
    imgsz=512,
    batch=4,
    device=0,
    trainer=YOLOEPETrainer,
    amp=False
)
# Out:
# Transferred 592/592 items from pretrained weights
# Ultralytics 8.3.237  Python-3.10.19 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...

# %%
results = YOLOE(r"C:\Users\ASUS\Desktop\promethean\som ting wong\runs\detect\train4\weights\best.pt") # Best Model Path
metrics = results.val()
# Out:
# Validate using the text prompt.
# ...
# Ultralytics 8.3.237  Python-3.10.19 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# YOLOe-11s summary (fused): 104 layers, 9,417,444 parameters, 0 gradients, 21.3 GFLOPs
# val: Fast image access  (ping: 2.44.8 ms, read: 49.411.7 MB/s, size: 22.8 KB)
# val: Scanning C:\Users\ASUS\Desktop\promethean\som ting wong\chess_pieces\valid\labels... 30 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 30/30 1.5Kit/s 0.0s
# val: New cache created: C:\Users\ASUS\Desktop\promethean\som ting wong\chess_pieces\valid\labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.1s/it 2.2s6.5s
#                    all         30        134       0.69      0.755      0.763      0.557
#                     BB          6          9      0.554      0.778      0.686      0.518
#                     BK          6          6      0.696      0.769      0.743      0.544
# ...

# %%
names = ['BB', 'BK', 'BKN', 'BP', 'BQ', 'BR', 'WB', 'WK', 'WKN', 'WP', 'WQ', 'WR']
results.set_classes(names, results.get_text_pe(names))
predi = results.predict("chess_7.jpg")
predi[0].show()
# Out:
# image 1/1 c:\Users\ASUS\Desktop\promethean\som ting wong\chess_7.jpg: 320x512 1 BK, 6 BPs, 2 BQs, 2 BRs, 1 WK, 1 WKN, 70.7ms
# Speed: 1.7ms preprocess, 70.7ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 512)

# %%
import torch
torch.cuda.empty_cache()
